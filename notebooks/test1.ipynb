# %%
from juice_core import SHTRestInterface

# %%
client = SHTRestInterface()

# %%
a = client.plan(36, as_pandas=False)

# %%
a.segments
# Out:
# [{'id': 86487,
#   'start': '2032-06-20T12:37:11.000Z',
#   'end': '2032-06-21T12:37:11.000Z',
#   'segment_definition': 'CALLISTO_FLYBY',
#   'overwritten': False,
#   'instrument_overwritten': False,
#   'timeline': 'WG1'},
#  {'id': 86488,
#   'start': '2032-07-28T13:48:51.000Z',
#   'end': '2032-07-29T13:48:51.000Z',
#   'segment_definition': 'CALLISTO_FLYBY',
#   'overwritten': False,
#   'instrument_overwritten': False,
#   'timeline': 'WG1'},
#  {'id': 86489,
#   'start': '2032-08-14T06:13:51.000Z',
#   'end': '2032-08-15T06:13:51.000Z',
#   'segment_definition': 'CALLISTO_FLYBY',
#   'overwritten': False,
#   'instrument_overwritten': False,
#   'timeline': 'WG1'},
#  {'id': 86490,
#   'start': '2032-09-10T07:25:31.000Z',
#   'end': '2032-09-11T07:25:31.000Z',
#   'segment_definition': 'CALLISTO_FLYBY',
#   'overwritten': False,
#   'instrument_overwritten': False,
#   'timeline': 'WG1'},
#  {'id': 86491,
#   'start': '2032-09-26T23:58:51.000Z',
# ...

# %%
client.plan_segments(36, as_pandas=True)
# Out:
#           id               start                 end segment_definition  \
# 0      86487 2032-06-20 12:37:11 2032-06-21 12:37:11     CALLISTO_FLYBY
# 1      86488 2032-07-28 13:48:51 2032-07-29 13:48:51     CALLISTO_FLYBY
# 2      86489 2032-08-14 06:13:51 2032-08-15 06:13:51     CALLISTO_FLYBY
# 3      86490 2032-09-10 07:25:31 2032-09-11 07:25:31     CALLISTO_FLYBY
# 4      86491 2032-09-26 23:58:51 2032-09-27 23:58:51     CALLISTO_FLYBY
# ...      ...                 ...                 ...                ...
# 11734  98272 2033-09-30 01:54:21 2033-10-04 03:04:21       JUPITER_TAIL
# 11735  98273 2033-10-21 06:23:21 2033-10-24 23:27:21       JUPITER_TAIL
# 11736  98274 2033-11-12 07:30:21 2033-11-22 01:19:21       JUPITER_TAIL
# 11737  98275 2034-11-28 11:19:01 2034-11-28 23:19:01       JMAG_CALROLL
# 11738  98276 2034-12-08 00:17:47 2034-12-08 12:17:47       JMAG_CALROLL
#
#        overwritten  instrument_overwritten timeline
# ...

# %%
client.pcw_by_mnemonic("PCW3")
# Out:
# name                                     PCW3
# mnemonic                                 PCW3
# description
# uevt_file                UEVT_JFCT_CCO3_00001
# sevt_file             EVT_SOC_PCW3_000072_S01
# git_branch                               PCW3
# baseline             APL_SOC_PCW3_SXXPYY.json
# start                    2025-03-20T00:00:00Z
# end                      2025-04-10T00:00:00Z
# ref_event_name                           COEV
# ref_event_counter                           3
# Name: 0, dtype: object

# %%
raise
# Out:
# ---------------------------------------------------------------------------
# RuntimeError                              Traceback (most recent call last)
# Cell In[6], line 1
# ----> 1 raise
#
# RuntimeError: No active exception to reraise

# %%
client.known_series(as_pandas=True)

# %%
client.series(series_name='sp_body_dist')

# %%
client.pcw()

# %%
client.pcw_by_mnemonic('PCW3')

# %%
got = client.series_multi(["sp_body_dist", "ssc_lat"])

# %%
ecco = await got

# %%
ecco[1]

# %%
client.event_types()

# %%
client.event_types(as_pandas=False)

# %%
client.events?

# %%
client.engineering_segments()

# %%
client.plans()

# %%
client.plan('CREMA_5_0_OPPORTUNITIES_v1', as_pandas=False)
