# %%
from copy import deepcopy
from pathlib import Path

import requests

# get the openapi def and update to 3.x
api_original = requests.get(
    "https://converter.swagger.io/api/convert?url=https%3A%2F%2Fjuicesoc.esac.esa.int%2Fdocs%2F%3Fformat%3Dopenapi",
).json()

outfile = Path("../openapi.json")

# %%
import re


def forge_id(optype, path):
    params = re.findall("{([^{}]+)}", path)

    for p in params:
        path = path.replace("{" + p + "}", "")

    if "rest_api" in path:
        path = path.replace("rest_api", "")

    path = re.sub(r"/+", "/", path)

    path = path.strip()

    path = path.strip("/")
    path = path.replace("/", "_")
    path = path.replace("-", "_")

    path = optype.lower() + "_" + path
    if len(params) > 0:
        return path + "_by_" + "_and_".join(params)
    return path

# %%
api = deepcopy(api_original)
ops = ["get", "post", "put", "delete", "patch"]

known_op_ids = []
known_test_ids = []

for k, item in api["paths"].items():
    print(f"Path {k}")
    for op in ops:
        if op in item.keys():
            it = item.get(op)

            new_op_id = forge_id(op, k)
            print(f"  -> suggested id {new_op_id}")
            if new_op_id in known_test_ids:
                print("  ------------ seems already taken!")
                raise
            else:
                it["operationId"] = new_op_id
                known_test_ids.append(new_op_id)
# Out:
# Path /api-token-auth/
#   -> suggested id post_api_token_auth
# Path /api-token-refresh/
#   -> suggested id post_api_token_refresh
# Path /rest_api/checks/
#   -> suggested id get_checks
# Path /rest_api/checks/{working_group_mnemonic}/
#   -> suggested id get_checks_by_working_group_mnemonic
# Path /rest_api/checks/{working_group_mnemonic}{format}
#   -> suggested id get_checks_by_working_group_mnemonic_and_format
# Path /rest_api/checks{format}
#   -> suggested id get_checks_by_format
# Path /rest_api/config/
#   -> suggested id get_config
# Path /rest_api/config{format}
#   -> suggested id get_config_by_format
# Path /rest_api/detailed_scenario/
#   -> suggested id get_detailed_scenario
#   -> suggested id post_detailed_scenario
# Path /rest_api/detailed_scenario/{id}/
#   -> suggested id get_detailed_scenario_by_id
# Path /rest_api/detailed_scenario/{id}{format}
#   -> suggested id get_detailed_scenario_by_id_and_format
# Path /rest_api/detailed_scenario{format}
#   -> suggested id get_detailed_scenario_by_format
#   -> suggested id post_detailed_scenario_by_format
# Path /rest_api/eps_package/
#   -> suggested id post_eps_package
# Path /rest_api/eps_package{format}
#   -> suggested id post_eps_package_by_format
# Path /rest_api/events/
#   -> suggested id get_events
# Path /rest_api/events{format}
#   -> suggested id get_events_by_format
# Path /rest_api/fdyn_event/
#   -> suggested id get_fdyn_event
# Path /rest_api/fdyn_event_definition/
#   -> suggested id get_fdyn_event_definition
# Path /rest_api/fdyn_event_definition{format}
#   -> suggested id get_fdyn_event_definition_by_format
# Path /rest_api/fdyn_event_file/
#   -> suggested id get_fdyn_event_file
# Path /rest_api/fdyn_event_file{format}
#   -> suggested id get_fdyn_event_file_by_format
# Path /rest_api/fdyn_event{format}
#   -> suggested id get_fdyn_event_by_format
# Path /rest_api/file/{filename}/
#   -> suggested id get_file_by_filename
# Path /rest_api/file/{filename}{format}
#   -> suggested id get_file_by_filename_and_format
# Path /rest_api/git/
#   -> suggested id get_git
# Path /rest_api/git/branches
#   -> suggested id get_git_branches
# Path /rest_api/git/branches{format}
#   -> suggested id get_git_branches_by_format
# Path /rest_api/git/{branch}/
#   -> suggested id get_git_by_branch
# Path /rest_api/git/{branch}/{hexsha}/
#   -> suggested id get_git_by_branch_and_hexsha
# Path /rest_api/git/{branch}/{hexsha}{format}
#   -> suggested id get_git_by_branch_and_hexsha_and_format
# Path /rest_api/git/{branch}{format}
#   -> suggested id get_git_by_branch_and_format
# Path /rest_api/git{format}
#   -> suggested id get_git_by_format
# Path /rest_api/mode/
#   -> suggested id get_mode
# Path /rest_api/mode{format}
#   -> suggested id get_mode_by_format
# Path /rest_api/observation_definition/
#   -> suggested id get_observation_definition
# Path /rest_api/observation_definition/{mnemonic}/
#   -> suggested id get_observation_definition_by_mnemonic
# Path /rest_api/observation_definition/{mnemonic}{format}
#   -> suggested id get_observation_definition_by_mnemonic_and_format
# Path /rest_api/observation_definition{format}
#   -> suggested id get_observation_definition_by_format
# Path /rest_api/pcw/
#   -> suggested id get_pcw
# Path /rest_api/pcw/units/
#   -> suggested id get_pcw_units
# Path /rest_api/pcw/units{format}
#   -> suggested id get_pcw_units_by_format
# Path /rest_api/pcw/{mnemonic}/
#   -> suggested id get_pcw_by_mnemonic
# Path /rest_api/pcw/{mnemonic}{format}
#   -> suggested id get_pcw_by_mnemonic_and_format
# Path /rest_api/pcw{format}
#   -> suggested id get_pcw_by_format
# Path /rest_api/plan/
#   -> suggested id get_plan
#   -> suggested id post_plan
# Path /rest_api/plan/{id}/
#   -> suggested id get_plan_by_id
#   -> suggested id put_plan_by_id
#   -> suggested id delete_plan_by_id
# Path /rest_api/plan/{id}/ptr
#   -> suggested id get_plan_ptr_by_id
# Path /rest_api/plan/{id}/ptr{format}
#   -> suggested id get_plan_ptr_by_id_and_format
# Path /rest_api/plan/{id}/stats
#   -> suggested id get_plan_stats_by_id
# Path /rest_api/plan/{id}/stats{format}
#   -> suggested id get_plan_stats_by_id_and_format
# Path /rest_api/plan/{id}{format}
#   -> suggested id get_plan_by_id_and_format
#   -> suggested id put_plan_by_id_and_format
#   -> suggested id delete_plan_by_id_and_format
# Path /rest_api/plan_ptr/
#   -> suggested id post_plan_ptr
# Path /rest_api/plan_ptr_skeleton/
#   -> suggested id post_plan_ptr_skeleton
# Path /rest_api/plan_ptr_skeleton{format}
#   -> suggested id post_plan_ptr_skeleton_by_format
# Path /rest_api/plan_ptr_xml/
#   -> suggested id post_plan_ptr_xml
# Path /rest_api/plan_ptr_xml{format}
#   -> suggested id post_plan_ptr_xml_by_format
# Path /rest_api/plan_ptr{format}
#   -> suggested id post_plan_ptr_by_format
# Path /rest_api/plan_simphony/groups/{id}/
#   -> suggested id get_plan_simphony_groups_by_id
# Path /rest_api/plan_simphony/groups/{id}{format}
#   -> suggested id get_plan_simphony_groups_by_id_and_format
# Path /rest_api/plan_simphony/opps/{id}/
#   -> suggested id get_plan_simphony_opps_by_id
# Path /rest_api/plan_simphony/opps/{id}{format}
#   -> suggested id get_plan_simphony_opps_by_id_and_format
# Path /rest_api/plan_simphony/timeline/{id}/
#   -> suggested id get_plan_simphony_timeline_by_id
# Path /rest_api/plan_simphony/timeline/{id}{format}
#   -> suggested id get_plan_simphony_timeline_by_id_and_format
# Path /rest_api/plan_simphony/{id}/
#   -> suggested id get_plan_simphony_by_id
# Path /rest_api/plan_simphony/{id}{format}
#   -> suggested id get_plan_simphony_by_id_and_format
# Path /rest_api/plan{format}
#   -> suggested id get_plan_by_format
#   -> suggested id post_plan_by_format
# Path /rest_api/plnview_file/
#   -> suggested id get_plnview_file
# Path /rest_api/plnview_file{format}
#   -> suggested id get_plnview_file_by_format
# Path /rest_api/plnview_sessions/
#   -> suggested id get_plnview_sessions
# Path /rest_api/plnview_sessions{format}
#   -> suggested id get_plnview_sessions_by_format
# Path /rest_api/segment_definition/{mnemonic}/
#   -> suggested id get_segment_definition_by_mnemonic
# Path /rest_api/segment_definition/{mnemonic}{format}
#   -> suggested id get_segment_definition_by_mnemonic_and_format
# Path /rest_api/series/
#   -> suggested id get_series
# Path /rest_api/series{format}
#   -> suggested id get_series_by_format
# Path /rest_api/session_flush/
#   -> suggested id get_session_flush
# Path /rest_api/session_flush{format}
#   -> suggested id get_session_flush_by_format
# Path /rest_api/trajectory/
#   -> suggested id get_trajectory
# Path /rest_api/trajectory/{mnemonic}/
#   -> suggested id get_trajectory_by_mnemonic
# Path /rest_api/trajectory/{mnemonic}/detailed_scenario
#   -> suggested id get_trajectory_detailed_scenario_by_mnemonic
# Path /rest_api/trajectory/{mnemonic}/detailed_scenario{format}
#   -> suggested id get_trajectory_detailed_scenario_by_mnemonic_and_format
# Path /rest_api/trajectory/{mnemonic}/engineering_segment_types
#   -> suggested id get_trajectory_engineering_segment_types_by_mnemonic
# Path /rest_api/trajectory/{mnemonic}/engineering_segment_types{format}
#   -> suggested id get_trajectory_engineering_segment_types_by_mnemonic_and_format
# Path /rest_api/trajectory/{mnemonic}/engineering_segments
#   -> suggested id get_trajectory_engineering_segments_by_mnemonic
# Path /rest_api/trajectory/{mnemonic}/engineering_segments{format}
#   -> suggested id get_trajectory_engineering_segments_by_mnemonic_and_format
# Path /rest_api/trajectory/{mnemonic}/event
#   -> suggested id get_trajectory_event_by_mnemonic
# Path /rest_api/trajectory/{mnemonic}/event{format}
#   -> suggested id get_trajectory_event_by_mnemonic_and_format
# Path /rest_api/trajectory/{mnemonic}/plan
#   -> suggested id get_trajectory_plan_by_mnemonic
# Path /rest_api/trajectory/{mnemonic}/plan{format}
#   -> suggested id get_trajectory_plan_by_mnemonic_and_format
# Path /rest_api/trajectory/{mnemonic}/ptr
#   -> suggested id get_trajectory_ptr_by_mnemonic
# Path /rest_api/trajectory/{mnemonic}/ptr{format}
#   -> suggested id get_trajectory_ptr_by_mnemonic_and_format
# Path /rest_api/trajectory/{mnemonic}/segment_definition
#   -> suggested id get_trajectory_segment_definition_by_mnemonic
# Path /rest_api/trajectory/{mnemonic}/segment_definition{format}
#   -> suggested id get_trajectory_segment_definition_by_mnemonic_and_format
# Path /rest_api/trajectory/{mnemonic}/series
#   -> suggested id get_trajectory_series_by_mnemonic
# Path /rest_api/trajectory/{mnemonic}/series{format}
#   -> suggested id get_trajectory_series_by_mnemonic_and_format
# Path /rest_api/trajectory/{mnemonic}{format}
#   -> suggested id get_trajectory_by_mnemonic_and_format
# Path /rest_api/trajectory{format}
#   -> suggested id get_trajectory_by_format
# Path /rest_api/user/{username}/
#   -> suggested id get_user_by_username
# Path /rest_api/user/{username}{format}
#   -> suggested id get_user_by_username_and_format
# Path /rest_api/uvt_event/{source}/
#   -> suggested id get_uvt_event_by_source
# Path /rest_api/uvt_event/{source}{format}
#   -> suggested id get_uvt_event_by_source_and_format
# Path /rest_api/uvt_event_file/
#   -> suggested id get_uvt_event_file
# Path /rest_api/uvt_event_file{format}
#   -> suggested id get_uvt_event_file_by_format
# Path /rest_api/version/
#   -> suggested id get_version
# Path /rest_api/version{format}
#   -> suggested id get_version_by_format

# %%
def find_by_op_id(api, operationId, return_parent_path=False):
    for k, item in api["paths"].items():
        for op in ops:
            if op in item.keys():
                it = item.get(op)
                op_id = it.get("operationId", None)

                if op_id == operationId:
                    if return_parent_path:
                        return item
                    return it

    return None

# %%
BODY_PARAMETER_DEFINITION = {
    "name": "body",
    "in": "query",
    "required": True,
    "schema": {"type": "string"},
}


def add_parameter(
    operation_id,
    api,
    definition=BODY_PARAMETER_DEFINITION,
):
    path = find_by_op_id(api, operation_id, return_parent_path=True)
    pars = path.get("parameters", [])

    name = definition["name"]
    for item in pars:
        if name == item["name"]:
            return

    pars.append(definition)

    path["parameters"] = pars
    print("fixed!")

# %%
def fix_content_as_array(operation_id, api):
    item = find_by_op_id(api, operation_id)
    try:
        ref = item["responses"]["200"]["content"]["application/json"]["schema"]["$ref"]
    except KeyError:
        return

    newschema = dict(type="array", items={"$ref": ref})

    item["responses"]["200"]["content"]["application/json"]["schema"] = newschema
    print('Fixed as array!')

# %%
# FIXES

add_parameter("get_series", api, BODY_PARAMETER_DEFINITION)
add_parameter("get_events",api, BODY_PARAMETER_DEFINITION)
fix_content_as_array( "get_plan", api)
# Out:
# fixed!
# fixed!
# Fixed as array!

# %%
import json

with outfile.open("w") as f:
    json.dump(api, f, indent=4)

# %%
# now genrate the module
# Execute the command in the specified directory


import subprocess

command = "poetry run openapi-python-client generate --path openapi.json --overwrite --meta=none --output-path=./src/juice_core_uplink_api_client/".split()

result = subprocess.run(
    command, cwd=outfile.parent, capture_output=True, text=True, check=False
)

# Print the output
print(result.stdout)
# Out:
# Generating src/juice_core_uplink_api_client
